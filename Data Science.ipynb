# %%
#uniquement la première fois
Pkg.add("DataFrames")
Pkg.add("Gadfly")
Pkg.add("RDatasets")
Pkg.add("Clustering")
# Out:
# INFO: Nothing to be done
# INFO: METADATA is out-of-date — you may not have the latest version of DataFrames
# INFO: Use `Pkg.update()` to get the latest versions of your packages
# INFO: Nothing to be done
# INFO: METADATA is out-of-date — you may not have the latest version of Gadfly
# INFO: Use `Pkg.update()` to get the latest versions of your packages
# INFO: Cloning cache of RDatasets from git://github.com/johnmyleswhite/RDatasets.jl.git
# INFO: Installing RDatasets v0.1.3
# INFO: Package database updated
# INFO: METADATA is out-of-date — you may not have the latest version of RDatasets
# INFO: Use `Pkg.update()` to get the latest versions of your packages
# INFO: No packages to install, update or remove
# INFO: Package database updated
# INFO: METADATA is out-of-date — you may not have the latest version of Clustering
# INFO: Use `Pkg.update()` to get the latest versions of your packages

# %%
using DataFrames

# %%
#définition d'une premier dataframe
df1=DataFrame(X1=[1,3,5],X2=rand(3))
# Out:
# 3×2 DataFrames.DataFrame
# │ Row │ X1 │ X2       │
# ├─────┼────┼──────────┤
# │ 1   │ 1  │ 0.706933 │
# │ 2   │ 3  │ 0.237878 │
# │ 3   │ 5  │ 0.742489 │

# %%
#on récupère un jeu de données
using RDatasets
iris=dataset("datasets","iris")
# Out:
# 150×5 DataFrames.DataFrame
# │ Row │ SepalLength │ SepalWidth │ PetalLength │ PetalWidth │ Species     │
# ├─────┼─────────────┼────────────┼─────────────┼────────────┼─────────────┤
# │ 1   │ 5.1         │ 3.5        │ 1.4         │ 0.2        │ "setosa"    │
# │ 2   │ 4.9         │ 3.0        │ 1.4         │ 0.2        │ "setosa"    │
# │ 3   │ 4.7         │ 3.2        │ 1.3         │ 0.2        │ "setosa"    │
# │ 4   │ 4.6         │ 3.1        │ 1.5         │ 0.2        │ "setosa"    │
# │ 5   │ 5.0         │ 3.6        │ 1.4         │ 0.2        │ "setosa"    │
# │ 6   │ 5.4         │ 3.9        │ 1.7         │ 0.4        │ "setosa"    │
# │ 7   │ 4.6         │ 3.4        │ 1.4         │ 0.3        │ "setosa"    │
# │ 8   │ 5.0         │ 3.4        │ 1.5         │ 0.2        │ "setosa"    │
# │ 9   │ 4.4         │ 2.9        │ 1.4         │ 0.2        │ "setosa"    │
# │ 10  │ 4.9         │ 3.1        │ 1.5         │ 0.1        │ "setosa"    │
# ...

# %%
describe(iris)
# Out:
# SepalLength
# Min      4.3
# 1st Qu.  5.1
# Median   5.8
# Mean     5.843333333333334
# 3rd Qu.  6.4
# Max      7.9
# NAs      0
# NA%      0.0%
#
# SepalWidth
# Min      2.0
# 1st Qu.  2.8
# Median   3.0
# Mean     3.0573333333333332
# 3rd Qu.  3.3
# Max      4.4
# NAs      0
# NA%      0.0%
#
# PetalLength
# Min      1.0
# 1st Qu.  1.6
# Median   4.35
# Mean     3.7579999999999996
# 3rd Qu.  5.1
# Max      6.9
# NAs      0
# NA%      0.0%
#
# PetalWidth
# Min      0.1
# 1st Qu.  0.3
# Median   1.3
# Mean     1.1993333333333331
# 3rd Qu.  1.8
# Max      2.5
# NAs      0
# NA%      0.0%
#
# Species
# Length  150
# Type    Pooled Union{ASCIIString,UTF8String}
# NAs     0
# NA%     0.0%
# Unique  3

# %%
#récupération d'un fichier csv
df2=readtable("Advertising.csv")
# Out:
# 200×5 DataFrames.DataFrame
# │ Row │ x   │ TV    │ Radio │ Newspaper │ Sales │
# ├─────┼─────┼───────┼───────┼───────────┼───────┤
# │ 1   │ 1   │ 230.1 │ 37.8  │ 69.2      │ 22.1  │
# │ 2   │ 2   │ 44.5  │ 39.3  │ 45.1      │ 10.4  │
# │ 3   │ 3   │ 17.2  │ 45.9  │ 69.3      │ 9.3   │
# │ 4   │ 4   │ 151.5 │ 41.3  │ 58.5      │ 18.5  │
# │ 5   │ 5   │ 180.8 │ 10.8  │ 58.4      │ 12.9  │
# │ 6   │ 6   │ 8.7   │ 48.9  │ 75.0      │ 7.2   │
# │ 7   │ 7   │ 57.5  │ 32.8  │ 23.5      │ 11.8  │
# │ 8   │ 8   │ 120.2 │ 19.6  │ 11.6      │ 13.2  │
# │ 9   │ 9   │ 8.6   │ 2.1   │ 1.0       │ 4.8   │
# │ 10  │ 10  │ 199.8 │ 2.6   │ 21.2      │ 10.6  │
# │ 11  │ 11  │ 66.1  │ 5.8   │ 24.2      │ 8.6   │
# ⋮
# │ 189 │ 189 │ 286.0 │ 13.9  │ 3.7       │ 15.9  │
# │ 190 │ 190 │ 18.7  │ 12.1  │ 23.4      │ 6.7   │
# │ 191 │ 191 │ 39.5  │ 41.1  │ 5.8       │ 10.8  │
# │ 192 │ 192 │ 75.5  │ 10.8  │ 6.0       │ 9.9   │
# │ 193 │ 193 │ 17.2  │ 4.1   │ 31.6      │ 5.9   │
# ...

# %% [markdown]
# ### Graphiques avec Julia et Gadfly

# %%
using Gadfly

# %%
plot(x=rand(5),y=rand(5))
# Out:
# Plot(...)

# %%
plot(iris,x="SepalLength",y="SepalWidth")
# Out:
# Plot(...)

# %%
#on va faire un clustering avec les k-means et représenter les résultats
using Clustering
# Out:
# INFO: Precompiling module ArrayViews...

# %%
X=rand(10,1000)
R=kmeans(X,3)
# Out:
# Clustering.KmeansResult{Float64}(10x3 Array{Float64,2}:
#  0.43233   0.508889  0.523567
#  0.497331  0.496222  0.471416
#  0.506398  0.553736  0.49937
#  0.494435  0.523066  0.488225
#  0.323803  0.53353   0.567837
#  0.59107   0.460116  0.444767
#  0.385338  0.605672  0.465938
#  0.672724  0.367112  0.493237
#  0.270989  0.550501  0.625331
#  0.520652  0.745012  0.235792,[2,2,1,1,2,1,1,1,3,2  …  1,3,2,3,3,2,3,3,1,2],[0.685906,0.442546,0.733147,0.85142,0.449323,0.752484,0.456613,0.824031,0.33771,0.659177  …  1.04439,0.416517,0.467652,0.479304,0.566888,0.611827,1.02209,0.528582,0.779589,0.343257],[307,359,334],[307.0,359.0,334.0],717.7661750427966,15,true)

# %%
nclusters(R)
# Out:
# 3

# %%
plot(x=X[1,:],y=X[2,:],color=assignments(R), Geom.point)
# Out:
# Plot(...)
